# %%
from pymongo import MongoClient

# %%
import os 
connection_string = os.getenv("MONGO_DB_URL")

# %%
client = MongoClient(connection_string)
print(client)
# Out:
# MongoClient(host=['ac-vet6dpt-shard-00-00.cbyjt1r.mongodb.net:27017', 'ac-vet6dpt-shard-00-01.cbyjt1r.mongodb.net:27017', 'ac-vet6dpt-shard-00-02.cbyjt1r.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-oodc9b-shard-0', ssl=True)

# %%
db = client['liveclass']

# %%
collection = db["mongoclass"]

# %%
data={
    "name":"Binni",
    "age":21,
    "email":"pankajbinni@gmail.com"
}

# %%
collection.insert_one(data)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('696528243a49980194d2a292'), 'name': 'Binni', 'age': 21, 'email': 'pankajbinni@gmail.com'}
